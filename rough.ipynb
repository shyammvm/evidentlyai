# %%
import pandas as pd
import numpy as np

# %%
#classification
bcancer_curr = pd.read_csv(r'dataset\regression\housing_cur.csv')
bcancer_curr.head()
# Out:
#     MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0   4.1250       9.0  6.655582   1.118765      1155.0  2.743468     33.52
# 1   5.0951      33.0  5.526448   1.181360       987.0  2.486146     33.80
# 2   2.7868      15.0  5.338129   1.009592      1004.0  2.407674     38.70
# 3  10.8082      42.0  7.410448   0.970149       368.0  2.746269     34.04
# 4   2.0089      44.0  4.461240   1.019380       518.0  2.007752     38.56
#
#    Longitude   target  prediction
# 0    -116.96  3.92100    6.384695
# 1    -118.34  3.18900    6.463384
# 2    -121.33  1.17800    1.943761
# 3    -118.52  5.00001    2.903780
# 4    -121.48  1.13600    1.039264

# %%
bcancer_label_cur = pd.read_csv('dataset/classification/bcancer_label_cur.csv')
bcancer_label_cur.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0       10.180         17.53           65.12      313.1          0.10610
# 1       14.860         16.94           94.89      673.7          0.08924
# 2        9.742         19.12           61.93      289.7          0.10750
# 3       10.260         14.71           66.20      321.6          0.09882
# 4       10.080         15.11           63.76      317.5          0.09267
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.08502        0.017680             0.019150         0.1910
# 1           0.07074        0.033460             0.028770         0.1573
# 2           0.08333        0.008934             0.019670         0.2538
# 3           0.09159        0.035810             0.020370         0.1633
# 4           0.04695        0.001597             0.002404         0.1703
#
#    mean fractal dimension  ...  worst perimeter  worst area  worst smoothness  \
# ...
